# %%
# Imports
import sys
import os

import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from PIL import Image, UnidentifiedImageError

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, TensorDataset
import torchvision.transforms as transforms
import torch.multiprocessing
torch.multiprocessing.set_sharing_strategy('file_system')

from torchvision.models import inception_v3, Inception_V3_Weights

from scipy.linalg import sqrtm

# %%
src_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'src'))
sys.path.insert(0, src_path)

# %%
from flow import Glow
from autoencoder import SpatialVAE

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
flow_model_file = "../models/flow_best.pth"
autoencoder_model_file = "../models/spatial_autoencoder.pth"
latent_data_file = "../data/latents.npz"

# %%
flow = torch.load(flow_model_file, weights_only=False, map_location=device)
flow.to(device)
flow.eval()

autoencoder = torch.load(autoencoder_model_file, weights_only=False, map_location=device)
autoencoder.to(device)
autoencoder.eval()
# Out:
# SpatialVAE(
#   (encoder): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): SiLU()
#     (2): DownBlock(
#       (conv): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#       (act): SiLU()
#       (res): Sequential(
#         (0): ResBlock(
#           (block): Sequential(
#             (0): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (1): SiLU()
#             (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (3): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (4): SiLU()
#             (5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#         )
#         (1): ResBlock(
#           (block): Sequential(
#             (0): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (1): SiLU()
#             (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (3): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (4): SiLU()
#             (5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#         )
#       )
#     )
#     (3): DownBlock(
#       (conv): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (act): SiLU()
#       (res): Sequential(
#         (0): ResBlock(
#           (block): Sequential(
#             (0): GroupNorm(8, 128, eps=1e-05, affine=True)
#             (1): SiLU()
#             (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (3): GroupNorm(8, 128, eps=1e-05, affine=True)
#             (4): SiLU()
#             (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#         )
#         (1): ResBlock(
#           (block): Sequential(
#             (0): GroupNorm(8, 128, eps=1e-05, affine=True)
#             (1): SiLU()
#             (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (3): GroupNorm(8, 128, eps=1e-05, affine=True)
#             (4): SiLU()
#             (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#         )
#       )
#     )
#     (4): SelfAttention(
#       (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (attn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#       )
#     )
#     (5): DownBlock(
#       (conv): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#       (act): SiLU()
#       (res): Sequential(
#         (0): ResBlock(
#           (block): Sequential(
#             (0): GroupNorm(8, 256, eps=1e-05, affine=True)
#             (1): SiLU()
#             (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (3): GroupNorm(8, 256, eps=1e-05, affine=True)
#             (4): SiLU()
#             (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#         )
#         (1): ResBlock(
#           (block): Sequential(
#             (0): GroupNorm(8, 256, eps=1e-05, affine=True)
#             (1): SiLU()
#             (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (3): GroupNorm(8, 256, eps=1e-05, affine=True)
#             (4): SiLU()
#             (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#         )
#       )
#     )
#     (6): SelfAttention(
#       (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#       (attn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#       )
#     )
#     (7): ResBlock(
#       (block): Sequential(
#         (0): GroupNorm(8, 256, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (3): GroupNorm(8, 256, eps=1e-05, affine=True)
#         (4): SiLU()
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (8): ResBlock(
#       (block): Sequential(
#         (0): GroupNorm(8, 256, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (3): GroupNorm(8, 256, eps=1e-05, affine=True)
#         (4): SiLU()
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#   )
#   (to_mean): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#   (to_logvar): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#   (from_latent): Sequential(
#     (0): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): GroupNorm(8, 256, eps=1e-05, affine=True)
#     (2): SiLU()
#   )
#   (decoder): Sequential(
#     (0): ResBlock(
#       (block): Sequential(
#         (0): GroupNorm(8, 256, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (3): GroupNorm(8, 256, eps=1e-05, affine=True)
#         (4): SiLU()
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (1): ResBlock(
#       (block): Sequential(
#         (0): GroupNorm(8, 256, eps=1e-05, affine=True)
#         (1): SiLU()
#         (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (3): GroupNorm(8, 256, eps=1e-05, affine=True)
#         (4): SiLU()
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (2): SelfAttention(
#       (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#       (attn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#       )
#     )
#     (3): UpBlock(
#       (up): Sequential(
#         (0): Upsample(scale_factor=2.0, mode='nearest')
#         (1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): GroupNorm(8, 128, eps=1e-05, affine=True)
#         (3): SiLU()
#       )
#       (res): Sequential(
#         (0): ResBlock(
#           (block): Sequential(
#             (0): GroupNorm(8, 128, eps=1e-05, affine=True)
#             (1): SiLU()
#             (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (3): GroupNorm(8, 128, eps=1e-05, affine=True)
#             (4): SiLU()
#             (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#         )
#         (1): ResBlock(
#           (block): Sequential(
#             (0): GroupNorm(8, 128, eps=1e-05, affine=True)
#             (1): SiLU()
#             (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (3): GroupNorm(8, 128, eps=1e-05, affine=True)
#             (4): SiLU()
#             (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#         )
#       )
#     )
#     (4): SelfAttention(
#       (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (attn): MultiheadAttention(
#         (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#       )
#     )
#     (5): UpBlock(
#       (up): Sequential(
#         (0): Upsample(scale_factor=2.0, mode='nearest')
#         (1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (3): SiLU()
#       )
#       (res): Sequential(
#         (0): ResBlock(
#           (block): Sequential(
#             (0): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (1): SiLU()
#             (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (3): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (4): SiLU()
#             (5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#         )
#         (1): ResBlock(
#           (block): Sequential(
#             (0): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (1): SiLU()
#             (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (3): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (4): SiLU()
#             (5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#         )
#       )
#     )
#     (6): UpBlock(
#       (up): Sequential(
#         (0): Upsample(scale_factor=2.0, mode='nearest')
#         (1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): GroupNorm(8, 32, eps=1e-05, affine=True)
#         (3): SiLU()
#       )
#       (res): Sequential(
#         (0): ResBlock(
#           (block): Sequential(
#             (0): GroupNorm(8, 32, eps=1e-05, affine=True)
#             (1): SiLU()
#             (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (3): GroupNorm(8, 32, eps=1e-05, affine=True)
#             (4): SiLU()
#             (5): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#         )
#         (1): ResBlock(
#           (block): Sequential(
#             (0): GroupNorm(8, 32, eps=1e-05, affine=True)
#             (1): SiLU()
#             (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (3): GroupNorm(8, 32, eps=1e-05, affine=True)
#             (4): SiLU()
#             (5): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#         )
#       )
#     )
#     (7): GroupNorm(8, 32, eps=1e-05, affine=True)
#     (8): SiLU()
#     (9): Conv2d(32, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )

# %%
# load data
data = np.load(latent_data_file)
latents_tensor = torch.from_numpy(data['latents'].astype(np.float32))
latents_mean_tensor = torch.from_numpy(data['latents_mean'].astype(np.float32))
latents_std_tensor = torch.from_numpy(data['latents_std'].astype(np.float32))

# %%
@torch.no_grad()
def generate_faces(autoencoder, flow, n_samples=16, temperature=0.7):
    autoencoder.eval()
    flow.eval()
    device = next(autoencoder.parameters()).device

    # Glow generates spatial latents
    latent_normalized = flow.sample(n_samples, device=device, temperature=0.1)
    latent = latent_normalized * latents_std_tensor + latents_mean_tensor

    images = autoencoder.decode(latent)
    return images.cpu().clamp(0, 1)

# %%
import matplotlib.pyplot as plt
import torchvision.utils as vutils

# Generate images
images = generate_faces(autoencoder, flow, n_samples=4, temperature=1.0)

# Make grid
grid = vutils.make_grid(images, nrow=4, normalize=True)

# Plot
plt.figure(figsize=(16, 4))
plt.imshow(grid.permute(1, 2, 0))
plt.axis("off")

# Save
# plt.savefig("../imgs/generated_face.png", dpi=300, bbox_inches="tight", pad_inches=0)
# plt.savefig("../imgs/generated_face.pdf", bbox_inches="tight", pad_inches=0)

plt.show()

# %%
import os
import numpy as np
from PIL import Image
from tqdm import tqdm

fake_dir = "../data/fid/fakes"
os.makedirs(fake_dir, exist_ok=True)

# optional: clear old generated images
for f in os.listdir(fake_dir):
    os.remove(os.path.join(fake_dir, f))

@torch.no_grad()
def save_generated_images(autoencoder, flow, out_dir, n_total=500, batch_size=25, temperature=1.0):
    os.makedirs(out_dir, exist_ok=True)
    img_idx = 0
    for _ in tqdm(range(int(np.ceil(n_total / batch_size)))):
        current_bs = min(batch_size, n_total - img_idx)
        if current_bs <= 0:
            break
        images = generate_faces(autoencoder, flow, n_samples=current_bs, temperature=temperature)
        images = images.detach().cpu()
        for i in range(images.size(0)):
            img = images[i]
            if img.shape[0] == 1:
                arr = (img[0].numpy() * 255).clip(0, 255).astype(np.uint8)
                arr_rgb = np.stack([arr, arr, arr], axis=-1)  # HxW -> HxWx3
                pil_img = Image.fromarray(arr_rgb, mode="RGB")
            else:
                arr = (img.permute(1, 2, 0).numpy() * 255).clip(0, 255).astype(np.uint8)
                pil_img = Image.fromarray(arr)
            pil_img.save(os.path.join(out_dir, f"fake_{img_idx:05d}.png"))
            img_idx += 1

save_generated_images(autoencoder, flow, fake_dir, n_total=500, batch_size=25, temperature=1.0)
print("Saved generated images to:", fake_dir)
# Out:
#  20%|█████████████████████▍                                                                                     | 4/20 [00:03<00:14,  1.12it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 35
#      32             pil_img.save(os.path.join(out_dir, f"fake_{img_idx:05d}.png"))
#      33             img_idx += 1
# ---> 35 save_generated_images(autoencoder, flow, fake_dir, n_total=500, batch_size=25, temperature=1.0)
#      36 print("Saved generated images to:", fake_dir)
#
# File ~/Desktop/code/engs106/.venv/lib/python3.14/site-packages/torch/utils/_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# Cell In[14], line 21, in save_generated_images(autoencoder, flow, out_dir, n_total, batch_size, temperature)
#      19 if current_bs <= 0:
#      20     break
# ---> 21 images = generate_faces(autoencoder, flow, n_samples=current_bs, temperature=temperature)
#      22 images = images.detach().cpu()
#      23 for i in range(images.size(0)):
#
# File ~/Desktop/code/engs106/.venv/lib/python3.14/site-packages/torch/utils/_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# Cell In[9], line 11, in generate_faces(autoencoder, flow, n_samples, temperature)
#       8 latent_normalized = flow.sample(n_samples, device=device, temperature=0.1)
#       9 latent = latent_normalized * latents_std_tensor + latents_mean_tensor
# ---> 11 images = autoencoder.decode(latent)
#      12 return images.cpu().clamp(0, 1)
#
# File ~/Desktop/code/engs106/engs106-project/src/autoencoder.py:162, in SpatialVAE.decode(self, z)
#     160 def decode(self, z):
#     161     h = self.from_latent(z)
# --> 162     recon = self.decoder(h)
#     164     return recon
#
# File ~/Desktop/code/engs106/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/code/engs106/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/Desktop/code/engs106/.venv/lib/python3.14/site-packages/torch/nn/modules/container.py:253, in Sequential.forward(self, input)
#     249 """
#     250 Runs the forward pass.
#     251 """
#     252 for module in self:
# --> 253     input = module(input)
#     254 return input
#
# File ~/Desktop/code/engs106/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/code/engs106/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/Desktop/code/engs106/engs106-project/src/autoencoder.py:66, in UpBlock.forward(self, x)
#      64 def forward(self, x):
#      65     x = self.up(x)
# ---> 66     x = self.res(x)
#      67     return x
#
# File ~/Desktop/code/engs106/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/code/engs106/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/Desktop/code/engs106/.venv/lib/python3.14/site-packages/torch/nn/modules/container.py:253, in Sequential.forward(self, input)
#     249 """
#     250 Runs the forward pass.
#     251 """
#     252 for module in self:
# --> 253     input = module(input)
#     254 return input
#
# File ~/Desktop/code/engs106/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/code/engs106/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/Desktop/code/engs106/engs106-project/src/autoencoder.py:23, in ResBlock.forward(self, x)
#      22 def forward(self, x):
# ---> 23     return x + self.block(x)
#
# File ~/Desktop/code/engs106/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/code/engs106/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/Desktop/code/engs106/.venv/lib/python3.14/site-packages/torch/nn/modules/container.py:253, in Sequential.forward(self, input)
#     249 """
#     250 Runs the forward pass.
#     251 """
#     252 for module in self:
# --> 253     input = module(input)
#     254 return input
#
# File ~/Desktop/code/engs106/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/code/engs106/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/Desktop/code/engs106/.venv/lib/python3.14/site-packages/torch/nn/modules/activation.py:472, in SiLU.forward(self, input)
#     468 def forward(self, input: Tensor) -> Tensor:
#     469     """
#     470     Runs the forward pass.
#     471     """
# --> 472     return F.silu(input, inplace=self.inplace)
#
# File ~/Desktop/code/engs106/.venv/lib/python3.14/site-packages/torch/nn/functional.py:2395, in silu(input, inplace)
#    2393 if inplace:
#    2394     return torch._C._nn.silu_(input)
# -> 2395 return torch._C._nn.silu(input)
#
# KeyboardInterrupt:
